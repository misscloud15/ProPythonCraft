# %% [markdown]
# INTEGER DATATYPE

# %%
e = 101
f = 4024938408484942

# %%
print(e)
print(f)
# Out:
# 101
# 4024938408484942

# %%
import sys
sys.getsizeof(e)
# Out:
# 28

# %%
sys.getsizeof(f)
# Out:
# 32

# %% [markdown]
# Integer datatype is immutable

# %%
x = 1
print(x)
# Out:
# 1

# %%
id(x)
# Out:
# 11654376

# %%
x = 55
print
# Out:
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
id(x)
# Out:
# 11656104

# %% [markdown]
# FLOAT DATATYPE

# %%
g = 12.45
print(type(g))
# Out:
# <class 'float'>

# %% [markdown]
# 125000 =
# 125*1000 =
# 125*10^3 =
# 125*E3 =
# 125E3     125=mantisa and E3 is exponent

# %%
h = 125E3
print(h)
# Out:
# 125000.0

# %%
i = 125755E-2
print(i)
# Out:
# 1257.55

# %%
j =1008
k = -1008
m =-2384E3
n = 84940e-4

# %%
print(j,k,m,n)
# Out:
# 1008 -1008 -2384000.0 8.494
