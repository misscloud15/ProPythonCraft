# %% [markdown]
# BOOL DATATYPE

# %%
x = True      # x = true is not allowed in python  NameError
y = False     # y = false is not allowed in python
print(x)
print(y)
# Out:
# True
# False

# %%
int(x)
# Out:
# 1

# %%
int(y)
# Out:
# 0

# %%
type(x)
type(y)
# Out:
# bool

# %%
a = 5
b = 60
a < b
# Out:
# True

# %%
a>b
# Out:
# False

# %% [markdown]
# COMPLEX DATATYPE

# %%
c = 10+3j
print(type(c))
# Out:
# <class 'complex'>

# %%
c
# Out:
# (10+3j)

# %%
c = complex(1,5)
print(c)
# Out:
# (1+5j)

# %%
c = complex(3)
c
# Out:
# (3+0j)
